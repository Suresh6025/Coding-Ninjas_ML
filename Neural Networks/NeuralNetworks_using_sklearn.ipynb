# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()

# %%
x = iris.data
y = iris.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
y_train
# Out:
# array([1, 0, 0, 1, 2, 1, 0, 1, 0, 1, 2, 0, 2, 0, 2, 1, 2, 1, 0, 1, 1, 2,
#        2, 2, 0, 1, 1, 0, 1, 0, 0, 1, 2, 2, 2, 2, 2, 2, 1, 1, 1, 0, 0, 0,
#        0, 1, 2, 2, 1, 0, 2, 0, 1, 0, 1, 0, 2, 1, 2, 0, 1, 0, 2, 2, 0, 0,
#        0, 1, 2, 2, 1, 1, 0, 0, 2, 1, 1, 2, 2, 0, 0, 1, 1, 0, 1, 0, 2, 1,
#        1, 0, 2, 2, 1, 0, 2, 2, 0, 1, 0, 1, 2, 0, 2, 1, 0, 2, 1, 0, 2, 0,
#        1, 1])

# %%
from sklearn.neural_network import MLPClassifier

# %%
neural_clf = MLPClassifier(max_iter=750)
neural_clf.fit(x_train, y_train)
# Out:
# MLPClassifier(max_iter=750)

# %%
neural_clf.score(x_test, y_test)
# Out:
# 1.0

# %% [markdown]
# ### The total number of Layers ( hidden layers + output layer)

# %%
neural_clf.coefs_
# Out:
# [array([[ 5.15653118e-01,  1.92425640e-01, -9.50997997e-02,
#          -4.85613451e-02, -6.45873440e-03,  4.85898459e-01,
#           1.52953000e-01, -1.21527162e-01,  5.14600151e-11,
#           1.39803999e-01,  1.86624197e-01,  1.16195556e-01,
#           1.10756403e-01, -1.07568180e-02,  1.60126897e-16,
#           6.22294178e-02, -3.92729235e-02,  1.08273951e-02,
#          -9.61755396e-02, -2.09345598e-06, -1.54493390e-02,
#           9.95492584e-02, -8.54463019e-02, -3.12788839e-02,
#          -2.04413229e-01,  4.81004506e-02,  1.06574710e-01,
#           5.89917805e-13,  1.11928423e-01,  2.64563390e-01,
#          -9.87523795e-14, -1.04734582e-01,  3.02763563e-13,
#           2.20638249e-01,  5.27195837e-02,  1.16496472e-01,
#           2.15366442e-01, -3.72862366e-03, -1.30548931e-02,
#          -1.65080354e-02,  1.39239398e-01,  4.31077055e-01,
#           2.19502639e-01,  4.21396559e-02,  2.49492172e-01,
#          -2.73708148e-01,  5.82802417e-02,  7.87376204e-02,
# ...

# %%
len(neural_clf.coefs_)
# Out:
# 2

# %% [markdown]
# ### The number of weights in each layer -

# %%
neural_clf.coefs_[0].shape, neural_clf.coefs_[1].shape
# Out:
# ((4, 100), (100, 3))

# %% [markdown]
# ### The number of biases ... in each layer

# %%
neural_clf.intercepts_[0].shape, neural_clf.intercepts_[1].shape
# Out:
# ((100,), (3,))

# %% [markdown]
# ## NLP on Movie_Reviews Dataset

# %%
from nltk.corpus import movie_reviews

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
print(len(movie_reviews.fileids('pos')))
print(len(movie_reviews.fileids('neg')))
# Out:
# 1000
# 1000

# %%
movie_reviews.words(movie_reviews.fileids('pos')[5])
# Out:
# ['on', 'june', '30', ',', '1960', ',', 'a', 'self', ...]

# %%
documents = []
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(fileid), category))
documents[:5]
# Out:
# [(['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...], 'neg'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'neg'),
#  (['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...], 'neg'),
#  (['"', 'quest', 'for', 'camelot', '"', 'is', 'warner', ...], 'neg'),
#  (['synopsis', ':', 'a', 'mentally', 'unstable', 'man', ...], 'neg')]

# %%
import random
random.shuffle(documents)
documents[:5]
# Out:
# [(['steve', 'martin', 'is', 'one', 'of', 'the', ...], 'neg'),
#  (['all', 'right', ',', 'all', 'right', ',', 'we', 'get', ...], 'neg'),
#  (['oh', 'god', 'how', 'many', 'john', 'grisham', ...], 'pos'),
#  (['"', 'i', 'know', 'what', 'you', 'did', 'last', ...], 'pos'),
#  (['"', 'marie', 'couldn', "'", 't', 'talk', ',', '"', ...], 'neg')]

# %%
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
lemmatizer = WordNetLemmatizer()
from nltk.corpus import stopwords
import string
stop_words = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stop_words.update(punctuations)
print(stop_words, string.punctuation)
# Out:
# {'this', 'these', 'having', '{', 'themselves', 's', 'out', 'up', 'until', 'hasn', "shan't", 'being', 'i', 'was', 'were', 'shouldn', ',', "didn't", "mightn't", 'me', 'they', 'him', "needn't", 'just', 'with', "you'll", 'after', 'why', 'himself', '-', 'd', 'not', '>', 'further', 'between', "couldn't", 'through', 'needn', 'against', 'during', 'now', 'doesn', 'yourselves', ':', "wouldn't", 'there', "hadn't", 'the', 'own', 'm', 'be', "won't", '/', '+', 'more', 'no', 'at', "it's", 'in', 'about', 'off', 'she', 'do', 'couldn', 'didn', 'my', 'if', 'your', "you'd", 'its', 'or', 'most', 'nor', "you're", 'does', 'weren', 'each', 'isn', 'because', '\\', 'it', 'which', 'again', 'y', 'whom', 'under', 'been', 'won', '[', '}', '&', 'hers', 'how', 'below', 'when', "doesn't", "shouldn't", 'any', '_', "mustn't", 'wouldn', 'herself', 'those', 'theirs', 'all', 'wasn', 'of', 'them', "that'll", 'don', 'ma', 'hadn', 'so', "hasn't", 'only', 'what', 'are', '^', 'other', 'same', 'our', 'that', 'such', "'", 'her', 'then', "haven't", 'ourselves', 'he', "isn't", 'has', 'yours', 'an', "don't", 'very', 'ours', '*', 're', 've', 'their', 'mightn', 'haven', 'myself', "you've", 'who', 'his', 'a', 'while', 'into', "should've", 'few', 'here', 'have', '.', 'can', 'to', '$', 'mustn', '#', 'and', 'once', 'too', "aren't", 'you', "wasn't", 'did', 'yourself', 'down', 'than', '"', '=', "weren't", 'will', 'doing', ')', '~', 'over', 'by', 'o', '|', 'itself', 'above', 'll', 'ain', 'but', '(', 'is', 'had', '`', 'aren', "she's", '!', 'where', '@', 'both', '<', 'some', ']', 'shan', 'as', 't', 'should', 'am', 'for', 'from', '%', '?', 'on', 'before', ';', 'we'} !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
from nltk.corpus import wordnet
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def clean_review(words):
    output_words = []
    for w in words:
        if w.lower() not in stop_words:
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
    return output_words

# %%
documents = [(clean_review(document), category) for document, category in documents]

# %%
print(documents[0])
# Out:
# (['steve', 'martin', 'one', 'funniest', 'men', 'alive', 'take', 'true', 'statement', 'disappointment', 'film', 'equal', 'mine', 'martin', 'hilarious', 'create', 'best', 'laugh', 'loud', 'experience', 'ever', 'take', 'place', 'movie', 'theater', 'find', 'old', 'television', 'series', 'base', 'moment', 'humor', 'wit', 'bilko', 'name', 'accident', 'head', 'army', 'motor', 'pool', 'group', 'passion', 'scheme', 'every', 'episode', 'involves', 'sergeant', 'men', 'one', 'another', 'hair', 'brain', 'plan', 'get', 'rich', 'quick', 'outwit', 'officer', 'base', 'mchale', 'navy', 'granddaddy', 'idea', 'behind', 'movie', 'difference', 'far', 'fetch', 'usually', 'goofy', 'television', 'series', 'funny', 'one', 'laugh', 'film', 'make', 'retains', 'goofiness', 'entertainment', 'everything', 'clean', 'obviously', 'make', 'hollywood', 'back', 'lot', 'look', 'every', 'bit', 'like', 'look', 'brand', 'new', 'even', 'old', 'beat', 'stuff', 'martin', 'remarkably', 'small', 'big', 'life', 'role', 'original', 'phil', 'silver', 'played', 'huckster', 'heart', 'gold', 'touch', 'sleaziness', 'martin', 'bilko', 'pale', 'imitation', 'semi', 'bright', 'spot', 'phil', 'hartman', 'bilko', 'arch', 'enemy', 'say', 'much', 'consider', 'martin', 'lackluster', 'character', 'hartman', 'leaf', 'dust'], 'neg')

# %%
training_documents = documents[0:1500]
testing_documents = documents[1500:]

# %%
all_words = []
for doc in training_documents:
    all_words += doc[0]

# %%
import nltk

# %%
freq = nltk.FreqDist(all_words) # Frequency Distribution i.e the freq of occurance of a particular word
common = freq.most_common(3000) # The most frequent words also referred as most_common(3000)
features = [i[0] for i in common]

# %%
def get_feature_dict(words):
    current_features = {}
    words_set = set(words)
    for w in features:
        current_features[w] = w in words_set
    return current_features

# %%
get_feature_dict(training_documents[0][0])
# Out:
# {'film': True,
#  'movie': True,
#  'one': True,
#  'make': True,
#  'like': True,
#  'character': True,
#  'get': True,
#  'see': False,
#  'time': False,
#  'go': False,
#  'well': False,
#  'scene': False,
#  'even': True,
#  'good': False,
#  'story': False,
#  'take': True,
#  'would': False,
#  'much': True,
#  'also': False,
#  'two': False,
#  'come': False,
#  'give': False,
#  'life': True,
#  'seem': False,
#  'way': False,
#  'bad': False,
#  'look': True,
#  '--': False,
#  'know': False,
#  'end': False,
#  'first': False,
#  'year': False,
#  'work': False,
#  'thing': False,
#  'plot': False,
#  'say': True,
#  'play': False,
#  'really': False,
#  'people': False,
#  'little': False,
#  'show': False,
#  'love': False,
#  'could': False,
#  'man': False,
#  'try': False,
#  'star': False,
#  'never': False,
#  'great': False,
#  'performance': False,
#  'best': True,
#  'director': False,
#  'new': True,
#  'big': True,
#  'action': False,
#  'many': False,
#  'actor': False,
#  'want': False,
#  'u': False,
#  'watch': False,
#  'find': True,
#  'think': False,
#  'role': True,
#  'act': False,
#  'something': False,
#  'another': True,
#  'turn': False,
#  'audience': False,
#  'day': False,
#  'back': True,
#  'still': False,
#  'world': False,
#  'however': False,
#  'set': False,
#  'old': True,
#  'comedy': False,
#  'use': False,
#  'feel': False,
#  'part': False,
#  'begin': False,
#  'real': False,
#  'every': True,
#  'guy': False,
#  'though': False,
#  'cast': False,
#  'enough': False,
#  'around': False,
#  'write': False,
#  'run': False,
#  'name': True,
#  'interest': False,
#  'last': False,
#  'fact': False,
#  'point': False,
#  'may': False,
#  'script': False,
#  'almost': False,
#  'woman': False,
#  'young': False,
#  'right': False,
#  'long': False,
#  'actually': False,
#  'effect': False,
#  'minute': False,
#  'nothing': False,
#  'played': True,
#  'funny': True,
#  'although': False,
#  'ever': True,
#  'place': True,
#  'lot': True,
#  'screen': False,
#  'friend': False,
#  'john': False,
#  'moment': True,
#  'line': False,
#  'since': False,
#  'become': False,
#  'start': False,
#  'kill': False,
#  'call': False,
#  'help': False,
#  'high': False,
#  'lead': False,
#  'original': True,
#  'without': False,
#  'tell': False,
#  'sequence': False,
#  'girl': False,
#  'least': False,
#  'family': False,
#  'problem': False,
#  'three': False,
#  'quite': False,
#  'rather': False,
#  'picture': False,
#  'laugh': True,
#  'might': False,
#  'bit': True,
#  'need': False,
#  'far': True,
#  'course': False,
#  'anything': False,
#  'alien': False,
#  'must': False,
#  'child': False,
#  'away': False,
#  'american': False,
#  'fall': False,
#  'hour': False,
#  'put': False,
#  'wife': False,
#  'keep': False,
#  'job': False,
#  'always': False,
#  'include': False,
#  'reason': False,
#  'follow': False,
#  'yet': False,
#  'special': False,
#  'attempt': False,
#  'kind': False,
#  'feature': False,
#  'head': True,
#  'fun': False,
#  'hard': False,
#  'lose': False,
#  'hand': False,
#  'half': False,
#  'hollywood': True,
#  'instead': False,
#  'night': False,
#  'men': True,
#  'human': False,
#  'let': False,
#  'probably': False,
#  'move': False,
#  'series': True,
#  'mind': False,
#  'sense': False,
#  'home': False,
#  'sure': False,
#  'shot': False,
#  'along': False,
#  'black': False,
#  'together': False,
#  'war': False,
#  'face': False,
#  'pretty': False,
#  'direct': False,
#  'becomes': False,
#  'force': False,
#  'idea': True,
#  'everything': True,
#  'money': False,
#  'kid': False,
#  'death': False,
#  'involve': False,
#  'dialogue': False,
#  'believe': False,
#  'fight': False,
#  'everyone': False,
#  'save': False,
#  'sex': False,
#  'father': False,
#  'release': False,
#  'whole': False,
#  'appear': False,
#  'couple': False,
#  'perhaps': False,
#  'boy': False,
#  'do': False,
#  'question': False,
#  'small': True,
#  'happen': False,
#  'music': False,
#  'city': False,
#  'next': False,
#  'talk': False,
#  'second': False,
#  'thought': False,
#  '2': False,
#  'horror': False,
#  'whose': False,
#  'expect': False,
#  'less': False,
#  'rest': False,
#  'eye': False,
#  'evil': False,
#  'meet': False,
#  'relationship': False,
#  'create': True,
#  'word': False,
#  'james': False,
#  'completely': False,
#  'case': False,
#  'especially': False,
#  'top': False,
#  'school': False,
#  'mother': False,
#  'care': False,
#  'mr': False,
#  'review': False,
#  'live': False,
#  'late': False,
#  'change': False,
#  'base': True,
#  '10': False,
#  'left': False,
#  'mean': False,
#  'lack': False,
#  'fan': False,
#  'group': True,
#  'several': False,
#  'michael': False,
#  'joke': False,
#  'anyone': False,
#  'true': True,
#  'humor': True,
#  'simply': False,
#  'book': False,
#  'different': False,
#  'writer': False,
#  'house': False,
#  'hit': False,
#  'suppose': False,
#  'sound': False,
#  'main': False,
#  'dead': False,
#  'brother': False,
#  'tv': False,
#  'town': False,
#  'else': False,
#  'style': False,
#  'unfortunately': False,
#  'entire': False,
#  'soon': False,
#  'entertain': False,
#  'add': False,
#  'side': False,
#  'power': False,
#  'matter': False,
#  'wrong': False,
#  'robert': False,
#  'either': False,
#  'found': False,
#  'wonder': False,
#  'murder': False,
#  'support': False,
#  'later': False,
#  'hero': False,
#  'full': False,
#  'comic': False,
#  'credit': False,
#  'enjoy': False,
#  'leave': False,
#  'present': False,
#  'car': False,
#  'element': False,
#  'open': False,
#  'final': False,
#  'provide': False,
#  'someone': False,
#  'stop': False,
#  'scream': False,
#  'viewer': False,
#  'note': False,
#  'son': False,
#  'deal': False,
#  'camera': False,
#  'title': False,
#  'behind': True,
#  'video': False,
#  'summer': False,
#  'return': False,
#  'person': False,
#  'nice': False,
#  'order': False,
#  'despite': False,
#  'miss': False,
#  'piece': False,
#  'able': False,
#  'often': False,
#  'david': False,
#  'team': False,
#  'daughter': False,
#  'die': False,
#  'killer': False,
#  'result': False,
#  'perfect': False,
#  'classic': False,
#  'voice': False,
#  'finally': False,
#  'version': False,
#  'maybe': False,
#  'thriller': False,
#  'sort': False,
#  'joe': False,
#  'close': False,
#  'kevin': False,
#  'fine': False,
#  'drama': False,
#  'past': False,
#  'production': False,
#  'break': False,
#  'theater': True,
#  'hope': False,
#  'stand': False,
#  'situation': False,
#  'earth': False,
#  'example': False,
#  'strong': False,
#  'event': False,
#  'consider': True,
#  'violence': False,
#  'body': False,
#  'room': False,
#  'cut': False,
#  'view': False,
#  'game': False,
#  'certainly': False,
#  'white': False,
#  'upon': False,
#  'early': False,
#  'beautiful': False,
#  'short': False,
#  'ask': False,
#  'heart': True,
#  'bring': False,
#  'talent': False,
#  'major': False,
#  'self': False,
#  'exactly': False,
#  'jackie': False,
#  'plan': True,
#  'nearly': False,
#  'dog': False,
#  'dream': False,
#  'state': False,
#  'ship': False,
#  'dark': False,
#  'light': False,
#  'computer': False,
#  'opening': False,
#  'worth': False,
#  'cop': False,
#  'guess': False,
#  'realize': False,
#  'art': False,
#  'jack': False,
#  'screenplay': False,
#  'obvious': False,
#  'simple': False,
#  'experience': True,
#  'fill': False,
#  'age': False,
#  'king': False,
#  'direction': False,
#  'form': False,
#  'level': False,
#  'stupid': False,
#  'hold': False,
#  'waste': False,
#  'oscar': False,
#  'figure': False,
#  'number': False,
#  'sometimes': False,
#  'rise': False,
#  'walk': False,
#  'four': False,
#  'wait': False,
#  'surprise': False,
#  'others': False,
#  'throughout': False,
#  'five': False,
#  'space': False,
#  '1': False,
#  'chase': False,
#  'fiction': False,
#  'saw': False,
#  'already': False,
#  'paul': False,
#  'offer': False,
#  'romantic': False,
#  'battle': False,
#  'genre': False,
#  'career': False,
#  'deep': False,
#  'member': False,
#  'novel': False,
#  'flick': False,
#  'attention': False,
#  'twist': False,
#  'learn': False,
#  'carry': False,
#  'lee': False,
#  'peter': False,
#  'husband': False,
#  'remember': False,
#  'touch': True,
#  'easy': False,
#  'york': False,
#  'villain': False,
#  'boring': False,
#  'dr': False,
#  'song': False,
#  'happens': False,
#  'parent': False,
#  'quickly': False,
#  'pull': False,
#  'charm': False,
#  'filmmaker': False,
#  'disney': False,
#  'wild': False,
#  'pace': False,
#  'drug': False,
#  'god': False,
#  'extremely': False,
#  'sequel': False,
#  'particularly': False,
#  'tom': False,
#  'yes': False,
#  'quality': False,
#  'chance': False,
#  'win': False,
#  'girlfriend': False,
#  'rock': False,
#  'de': False,
#  'planet': False,
#  'gun': False,
#  'shoot': False,
#  'usually': True,
#  'tale': False,
#  'actress': False,
#  'material': False,
#  'focus': False,
#  'mention': False,
#  'police': False,
#  'mostly': False,
#  'stay': False,
#  'truly': False,
#  'decide': False,
#  'emotional': False,
#  'type': False,
#  'large': False,
#  'detail': False,
#  'hell': False,
#  'secret': False,
#  'project': False,
#  'future': False,
#  'vampire': False,
#  'image': False,
#  'law': False,
#  'living': False,
#  'across': False,
#  'slow': False,
#  'manages': False,
#  'score': False,
#  'single': False,
#  'none': False,
#  'co': False,
#  'drive': False,
#  'sit': False,
#  'within': False,
#  'middle': False,
#  'escape': False,
#  'theme': False,
#  'cover': False,
#  'eventually': False,
#  'possible': False,
#  'steal': False,
#  'success': False,
#  'million': False,
#  'water': False,
#  'pay': False,
#  'smith': False,
#  'except': False,
#  'among': False,
#  'whether': False,
#  'poor': False,
#  'entertainment': True,
#  'fear': False,
#  'studio': False,
#  'flaw': False,
#  'low': False,
#  'obviously': True,
#  'premise': False,
#  'crew': False,
#  'america': False,
#  'stuff': True,
#  'local': False,
#  'science': False,
#  'understand': False,
#  'happy': False,
#  'cool': False,
#  'basically': False,
#  'wish': False,
#  'mission': False,
#  'easily': False,
#  'history': False,
#  'chris': False,
#  'hilarious': True,
#  'wonderful': False,
#  'mark': False,
#  'complete': False,
#  'william': False,
#  'cause': False,
#  'impressive': False,
#  'control': False,
#  'near': False,
#  'alone': False,
#  'suspense': False,
#  'straight': False,
#  'aspect': False,
#  'amaze': False,
#  '3': False,
#  'screenwriter': False,
#  'fast': False,
#  'reality': False,
#  'serious': False,
#  'van': False,
#  'crime': False,
#  'batman': False,
#  'critic': False,
#  'explain': False,
#  'jones': False,
#  'producer': False,
#  'robin': False,
#  'television': True,
#  'fly': False,
#  'red': False,
#  'fire': False,
#  'produce': False,
#  'agent': False,
#  'bill': False,
#  'office': False,
#  'george': False,
#  'presence': False,
#  'effort': False,
#  'subject': False,
#  'due': False,
#  'blood': False,
#  'told': False,
#  'street': False,
#  'certain': False,
#  'third': False,
#  'popular': False,
#  'important': False,
#  'read': False,
#  'mystery': False,
#  'attack': False,
#  'somehow': False,
#  'jim': False,
#  'country': False,
#  'appeal': False,
#  'teen': False,
#  'oh': False,
#  'motion': False,
#  'message': False,
#  'ryan': False,
#  'brings': False,
#  'doubt': False,
#  'musical': False,
#  'recent': False,
#  'prison': False,
#  'class': False,
#  'speak': False,
#  'previous': False,
#  'victim': False,
#  'successful': False,
#  'ago': False,
#  'rule': False,
#  'sexual': False,
#  'emotion': False,
#  'romance': False,
#  'throw': False,
#  'difficult': False,
#  'apparently': False,
#  'general': False,
#  'bunch': False,
#  'bob': False,
#  'effective': False,
#  'fail': False,
#  'ben': False,
#  'rich': True,
#  'dramatic': False,
#  'party': False,
#  'trouble': False,
#  'decides': False,
#  'dance': False,
#  'allow': False,
#  'anyway': False,
#  'clear': False,
#  'leaf': True,
#  'confuse': False,
#  'ability': False,
#  'predictable': False,
#  'smart': False,
#  'excellent': False,
#  'budget': False,
#  'annoy': False,
#  'lie': False,
#  'student': False,
#  'former': False,
#  'cross': False,
#  'somewhat': False,
#  'business': False,
#  'angel': False,
#  'brilliant': False,
#  'surprisingly': False,
#  'trailer': False,
#  'answer': False,
#  'date': False,
#  'company': False,
#  'definitely': False,
#  'williams': False,
#  'share': False,
#  'tone': False,
#  'intelligent': False,
#  'stone': False,
#  'rat': False,
#  'trek': False,
#  'choice': False,
#  'discover': False,
#  'personal': False,
#  'usual': False,
#  'handle': False,
#  'murphy': False,
#  'r': False,
#  'visual': False,
#  'towards': False,
#  'wedding': False,
#  'absolutely': False,
#  'truman': False,
#  'giant': False,
#  'us': False,
#  'capture': False,
#  'shock': False,
#  'familiar': False,
#  'animate': False,
#  'master': False,
#  'wear': False,
#  'b': False,
#  'bruce': False,
#  'similar': False,
#  'catch': False,
#  'grow': False,
#  'clever': False,
#  'track': False,
#  'adult': False,
#  '4': False,
#  'land': False,
#  'nature': False,
#  'term': False,
#  'favorite': False,
#  'bond': False,
#  'felt': False,
#  'potential': False,
#  'martin': True,
#  'pick': False,
#  'excite': False,
#  'suspect': False,
#  'ex': False,
#  'free': False,
#  'ultimately': False,
#  'huge': False,
#  'approach': False,
#  'prove': False,
#  'heard': False,
#  'la': False,
#  'step': False,
#  'seriously': False,
#  'box': False,
#  'beyond': False,
#  'color': False,
#  'likely': False,
#  'reveal': False,
#  'depth': False,
#  'travel': False,
#  'reach': False,
#  'unlike': False,
#  'richard': False,
#  'blue': False,
#  'society': False,
#  'sam': False,
#  'e': False,
#  'deliver': False,
#  'l': False,
#  'sister': False,
#  'hill': False,
#  'wood': False,
#  'non': False,
#  'otherwise': False,
#  'detective': False,
#  'cinema': False,
#  'park': False,
#  'inside': False,
#  'cold': False,
#  'personality': False,
#  'spirit': False,
#  'decent': False,
#  'door': False,
#  'continue': False,
#  'compare': False,
#  'strange': False,
#  'enjoyable': False,
#  'gag': False,
#  'dumb': False,
#  'arm': False,
#  'solid': False,
#  'sign': False,
#  'overall': False,
#  'disaster': False,
#  'succeed': False,
#  'particular': False,
#  'married': False,
#  'immediately': False,
#  'toy': False,
#  'thrill': False,
#  'week': False,
#  'amuse': False,
#  'mike': False,
#  'mess': False,
#  'sight': False,
#  'powerful': False,
#  'amount': False,
#  'hunt': False,
#  'mar': False,
#  'merely': False,
#  'player': False,
#  'scary': False,
#  '5': False,
#  'manage': False,
#  'race': False,
#  '90': False,
#  'treat': False,
#  'silly': False,
#  'key': False,
#  'cliche': False,
#  'today': False,
#  'various': False,
#  'grace': False,
#  'truth': False,
#  'ten': False,
#  'design': False,
#  'modern': False,
#  'join': False,
#  'cameron': False,
#  'hank': False,
#  'slightly': False,
#  'spend': False,
#  'roll': False,
#  'talented': False,
#  'government': False,
#  'appearance': False,
#  'month': False,
#  'west': False,
#  'hate': False,
#  'scott': False,
#  'island': False,
#  'steve': True,
#  'air': False,
#  'search': False,
#  'memorable': False,
#  'perfectly': False,
#  'drop': False,
#  'harry': False,
#  'fashion': False,
#  'neither': False,
#  'brought': False,
#  'impossible': False,
#  'political': False,
#  'tension': False,
#  'kiss': False,
#  'actual': False,
#  'rating': False,
#  'beauty': False,
#  'purpose': False,
#  'lover': False,
#  'train': False,
#  'club': False,
#  'fails': False,
#  'fi': False,
#  'max': False,
#  'strike': False,
#  'eddie': False,
#  'allen': False,
#  'sweet': False,
#  'list': False,
#  'partner': False,
#  'totally': False,
#  'mouth': False,
#  'introduce': False,
#  'haunt': False,
#  'earlier': False,
#  'sci': False,
#  'cannot': False,
#  'foot': False,
#  'building': False,
#  'suffer': False,
#  'pop': False,
#  'serve': False,
#  'adventure': False,
#  'frank': False,
#  'english': False,
#  'soundtrack': False,
#  'six': False,
#  'heavy': False,
#  'ridiculous': False,
#  'costume': False,
#  'notice': False,
#  'award': False,
#  'chan': False,
#  'quick': True,
#  'dress': False,
#  'menace': False,
#  'doctor': False,
#  'sell': False,
#  'monster': False,
#  'suit': False,
#  'bore': False,
#  'basic': False,
#  'animation': False,
#  'raise': False,
#  'leader': False,
#  'standard': False,
#  'atmosphere': False,
#  'struggle': False,
#  'flat': False,
#  'cheap': False,
#  'female': False,
#  'army': True,
#  'background': False,
#  'promise': False,
#  'opportunity': False,
#  'titanic': False,
#  'imagine': False,
#  'brief': False,
#  'minor': False,
#  'violent': False,
#  'ride': False,
#  'baby': False,
#  'require': False,
#  'woody': False,
#  'cinematography': False,
#  'suddenly': False,
#  'ground': False,
#  'bug': False,
#  'engage': False,
#  'cameo': False,
#  'dull': False,
#  'british': False,
#  'ghost': False,
#  'highly': False,
#  'animal': False,
#  'hear': False,
#  'plenty': False,
#  'private': False,
#  'impact': False,
#  'president': False,
#  'respect': False,
#  'edit': False,
#  'ii': False,
#  'steven': False,
#  '8': False,
#  'dollar': False,
#  'college': False,
#  'store': False,
#  'entirely': False,
#  'convincing': False,
#  'frame': False,
#  'front': False,
#  'language': False,
#  'grant': False,
#  'jerry': False,
#  'ape': False,
#  'episode': True,
#  'possibly': False,
#  'conclusion': False,
#  'road': False,
#  'seven': False,
#  'issue': False,
#  'godzilla': False,
#  'officer': True,
#  'test': False,
#  'common': False,
#  'french': False,
#  'encounter': False,
#  'lawyer': False,
#  'hardly': False,
#  'soldier': False,
#  'scientist': False,
#  'typical': False,
#  'edward': False,
#  'terrible': False,
#  'carrey': False,
#  'tarantino': False,
#  'rescue': False,
#  'development': False,
#  'slowly': False,
#  'creature': False,
#  'machine': False,
#  'recommend': False,
#  'tim': False,
#  'complex': False,
#  'rush': False,
#  'remain': False,
#  'thus': False,
#  'fantasy': False,
#  'chemistry': False,
#  'energy': False,
#  'travolta': False,
#  'period': False,
#  'brown': False,
#  'cinematic': False,
#  'sing': False,
#  'prof': False,
#  'hop': False,
#  'j': False,
#  'visit': False,
#  'longer': False,
#  'outside': False,
#  'sean': False,
#  'whatever': False,
#  'awful': False,
#  'hot': False,
#  'hong': False,
#  'clearly': False,
#  'okay': False,
#  'delivers': False,
#  'concept': False,
#  'realistic': False,
#  'draw': False,
#  'etc': False,
#  'meanwhile': False,
#  'criminal': False,
#  'constantly': False,
#  'admit': False,
#  'wall': False,
#  'forget': False,
#  'indeed': False,
#  'adam': False,
#  'thanks': False,
#  'fairly': False,
#  'sent': False,
#  'band': False,
#  'bizarre': False,
#  'spent': False,
#  'accent': False,
#  'storyline': False,
#  'singer': False,
#  'subplot': False,
#  'innocent': False,
#  'willis': False,
#  'brain': True,
#  'mary': False,
#  'frighten': False,
#  'subtle': False,
#  'ready': False,
#  'fellow': False,
#  'intrigue': False,
#  ...}

# %%
training_data = [(get_feature_dict(doc), category) for doc, category in training_documents]
testing_data = [(get_feature_dict(doc), category) for doc, category in testing_documents]

# %%
training_data[0]
# Out:
# ({'film': True,
#   'movie': True,
#   'one': True,
#   'make': True,
#   'like': True,
#   'character': True,
#   'get': True,
#   'see': False,
#   'time': False,
#   'go': False,
#   'well': False,
#   'scene': False,
#   'even': True,
#   'good': False,
#   'story': False,
#   'take': True,
#   'would': False,
#   'much': True,
#   'also': False,
#   'two': False,
#   'come': False,
#   'give': False,
#   'life': True,
#   'seem': False,
#   'way': False,
#   'bad': False,
#   'look': True,
#   '--': False,
#   'know': False,
#   'end': False,
#   'first': False,
#   'year': False,
#   'work': False,
#   'thing': False,
#   'plot': False,
#   'say': True,
#   'play': False,
#   'really': False,
#   'people': False,
#   'little': False,
#   'show': False,
#   'love': False,
#   'could': False,
#   'man': False,
#   'try': False,
#   'star': False,
#   'never': False,
#   'great': False,
#   'performance': False,
#   'best': True,
#   'director': False,
#   'new': True,
#   'big': True,
#   'action': False,
#   'many': False,
#   'actor': False,
#   'want': False,
#   'u': False,
#   'watch': False,
#   'find': True,
#   'think': False,
#   'role': True,
#   'act': False,
#   'something': False,
#   'another': True,
#   'turn': False,
#   'audience': False,
#   'day': False,
#   'back': True,
#   'still': False,
#   'world': False,
#   'however': False,
#   'set': False,
#   'old': True,
#   'comedy': False,
#   'use': False,
#   'feel': False,
#   'part': False,
#   'begin': False,
#   'real': False,
#   'every': True,
#   'guy': False,
#   'though': False,
#   'cast': False,
#   'enough': False,
#   'around': False,
#   'write': False,
#   'run': False,
#   'name': True,
#   'interest': False,
#   'last': False,
#   'fact': False,
#   'point': False,
#   'may': False,
#   'script': False,
#   'almost': False,
#   'woman': False,
#   'young': False,
#   'right': False,
#   'long': False,
#   'actually': False,
#   'effect': False,
#   'minute': False,
#   'nothing': False,
#   'played': True,
#   'funny': True,
#   'although': False,
#   'ever': True,
#   'place': True,
#   'lot': True,
#   'screen': False,
#   'friend': False,
#   'john': False,
#   'moment': True,
#   'line': False,
#   'since': False,
#   'become': False,
#   'start': False,
#   'kill': False,
#   'call': False,
#   'help': False,
#   'high': False,
#   'lead': False,
#   'original': True,
#   'without': False,
#   'tell': False,
#   'sequence': False,
#   'girl': False,
#   'least': False,
#   'family': False,
#   'problem': False,
#   'three': False,
#   'quite': False,
#   'rather': False,
#   'picture': False,
#   'laugh': True,
#   'might': False,
#   'bit': True,
#   'need': False,
#   'far': True,
#   'course': False,
#   'anything': False,
#   'alien': False,
#   'must': False,
#   'child': False,
#   'away': False,
#   'american': False,
#   'fall': False,
#   'hour': False,
#   'put': False,
#   'wife': False,
#   'keep': False,
#   'job': False,
#   'always': False,
#   'include': False,
#   'reason': False,
#   'follow': False,
#   'yet': False,
#   'special': False,
#   'attempt': False,
#   'kind': False,
#   'feature': False,
#   'head': True,
#   'fun': False,
#   'hard': False,
#   'lose': False,
#   'hand': False,
#   'half': False,
#   'hollywood': True,
#   'instead': False,
#   'night': False,
#   'men': True,
#   'human': False,
#   'let': False,
#   'probably': False,
#   'move': False,
#   'series': True,
#   'mind': False,
#   'sense': False,
#   'home': False,
#   'sure': False,
#   'shot': False,
#   'along': False,
#   'black': False,
#   'together': False,
#   'war': False,
#   'face': False,
#   'pretty': False,
#   'direct': False,
#   'becomes': False,
#   'force': False,
#   'idea': True,
#   'everything': True,
#   'money': False,
#   'kid': False,
#   'death': False,
#   'involve': False,
#   'dialogue': False,
#   'believe': False,
#   'fight': False,
#   'everyone': False,
#   'save': False,
#   'sex': False,
#   'father': False,
#   'release': False,
#   'whole': False,
#   'appear': False,
#   'couple': False,
#   'perhaps': False,
#   'boy': False,
#   'do': False,
#   'question': False,
#   'small': True,
#   'happen': False,
#   'music': False,
#   'city': False,
#   'next': False,
#   'talk': False,
#   'second': False,
#   'thought': False,
#   '2': False,
#   'horror': False,
#   'whose': False,
#   'expect': False,
#   'less': False,
#   'rest': False,
#   'eye': False,
#   'evil': False,
#   'meet': False,
#   'relationship': False,
#   'create': True,
#   'word': False,
#   'james': False,
#   'completely': False,
#   'case': False,
#   'especially': False,
#   'top': False,
#   'school': False,
#   'mother': False,
#   'care': False,
#   'mr': False,
#   'review': False,
#   'live': False,
#   'late': False,
#   'change': False,
#   'base': True,
#   '10': False,
#   'left': False,
#   'mean': False,
#   'lack': False,
#   'fan': False,
#   'group': True,
#   'several': False,
#   'michael': False,
#   'joke': False,
#   'anyone': False,
#   'true': True,
#   'humor': True,
#   'simply': False,
#   'book': False,
#   'different': False,
#   'writer': False,
#   'house': False,
#   'hit': False,
#   'suppose': False,
#   'sound': False,
#   'main': False,
#   'dead': False,
#   'brother': False,
#   'tv': False,
#   'town': False,
#   'else': False,
#   'style': False,
#   'unfortunately': False,
#   'entire': False,
#   'soon': False,
#   'entertain': False,
#   'add': False,
#   'side': False,
#   'power': False,
#   'matter': False,
#   'wrong': False,
#   'robert': False,
#   'either': False,
#   'found': False,
#   'wonder': False,
#   'murder': False,
#   'support': False,
#   'later': False,
#   'hero': False,
#   'full': False,
#   'comic': False,
#   'credit': False,
#   'enjoy': False,
#   'leave': False,
#   'present': False,
#   'car': False,
#   'element': False,
#   'open': False,
#   'final': False,
#   'provide': False,
#   'someone': False,
#   'stop': False,
#   'scream': False,
#   'viewer': False,
#   'note': False,
#   'son': False,
#   'deal': False,
#   'camera': False,
#   'title': False,
#   'behind': True,
#   'video': False,
#   'summer': False,
#   'return': False,
#   'person': False,
#   'nice': False,
#   'order': False,
#   'despite': False,
#   'miss': False,
#   'piece': False,
#   'able': False,
#   'often': False,
#   'david': False,
#   'team': False,
#   'daughter': False,
#   'die': False,
#   'killer': False,
#   'result': False,
#   'perfect': False,
#   'classic': False,
#   'voice': False,
#   'finally': False,
#   'version': False,
#   'maybe': False,
#   'thriller': False,
#   'sort': False,
#   'joe': False,
#   'close': False,
#   'kevin': False,
#   'fine': False,
#   'drama': False,
#   'past': False,
#   'production': False,
#   'break': False,
#   'theater': True,
#   'hope': False,
#   'stand': False,
#   'situation': False,
#   'earth': False,
#   'example': False,
#   'strong': False,
#   'event': False,
#   'consider': True,
#   'violence': False,
#   'body': False,
#   'room': False,
#   'cut': False,
#   'view': False,
#   'game': False,
#   'certainly': False,
#   'white': False,
#   'upon': False,
#   'early': False,
#   'beautiful': False,
#   'short': False,
#   'ask': False,
#   'heart': True,
#   'bring': False,
#   'talent': False,
#   'major': False,
#   'self': False,
#   'exactly': False,
#   'jackie': False,
#   'plan': True,
#   'nearly': False,
#   'dog': False,
#   'dream': False,
#   'state': False,
#   'ship': False,
#   'dark': False,
#   'light': False,
#   'computer': False,
#   'opening': False,
#   'worth': False,
#   'cop': False,
#   'guess': False,
#   'realize': False,
#   'art': False,
#   'jack': False,
#   'screenplay': False,
#   'obvious': False,
#   'simple': False,
#   'experience': True,
#   'fill': False,
#   'age': False,
#   'king': False,
#   'direction': False,
#   'form': False,
#   'level': False,
#   'stupid': False,
#   'hold': False,
#   'waste': False,
#   'oscar': False,
#   'figure': False,
#   'number': False,
#   'sometimes': False,
#   'rise': False,
#   'walk': False,
#   'four': False,
#   'wait': False,
#   'surprise': False,
#   'others': False,
#   'throughout': False,
#   'five': False,
#   'space': False,
#   '1': False,
#   'chase': False,
#   'fiction': False,
#   'saw': False,
#   'already': False,
#   'paul': False,
#   'offer': False,
#   'romantic': False,
#   'battle': False,
#   'genre': False,
#   'career': False,
#   'deep': False,
#   'member': False,
#   'novel': False,
#   'flick': False,
#   'attention': False,
#   'twist': False,
#   'learn': False,
#   'carry': False,
#   'lee': False,
#   'peter': False,
#   'husband': False,
#   'remember': False,
#   'touch': True,
#   'easy': False,
#   'york': False,
#   'villain': False,
#   'boring': False,
#   'dr': False,
#   'song': False,
#   'happens': False,
#   'parent': False,
#   'quickly': False,
#   'pull': False,
#   'charm': False,
#   'filmmaker': False,
#   'disney': False,
#   'wild': False,
#   'pace': False,
#   'drug': False,
#   'god': False,
#   'extremely': False,
#   'sequel': False,
#   'particularly': False,
#   'tom': False,
#   'yes': False,
#   'quality': False,
#   'chance': False,
#   'win': False,
#   'girlfriend': False,
#   'rock': False,
#   'de': False,
#   'planet': False,
#   'gun': False,
#   'shoot': False,
#   'usually': True,
#   'tale': False,
#   'actress': False,
#   'material': False,
#   'focus': False,
#   'mention': False,
#   'police': False,
#   'mostly': False,
#   'stay': False,
#   'truly': False,
#   'decide': False,
#   'emotional': False,
#   'type': False,
#   'large': False,
#   'detail': False,
#   'hell': False,
#   'secret': False,
#   'project': False,
#   'future': False,
#   'vampire': False,
#   'image': False,
#   'law': False,
#   'living': False,
#   'across': False,
#   'slow': False,
#   'manages': False,
#   'score': False,
#   'single': False,
#   'none': False,
#   'co': False,
#   'drive': False,
#   'sit': False,
#   'within': False,
#   'middle': False,
#   'escape': False,
#   'theme': False,
#   'cover': False,
#   'eventually': False,
#   'possible': False,
#   'steal': False,
#   'success': False,
#   'million': False,
#   'water': False,
#   'pay': False,
#   'smith': False,
#   'except': False,
#   'among': False,
#   'whether': False,
#   'poor': False,
#   'entertainment': True,
#   'fear': False,
#   'studio': False,
#   'flaw': False,
#   'low': False,
#   'obviously': True,
#   'premise': False,
#   'crew': False,
#   'america': False,
#   'stuff': True,
#   'local': False,
#   'science': False,
#   'understand': False,
#   'happy': False,
#   'cool': False,
#   'basically': False,
#   'wish': False,
#   'mission': False,
#   'easily': False,
#   'history': False,
#   'chris': False,
#   'hilarious': True,
#   'wonderful': False,
#   'mark': False,
#   'complete': False,
#   'william': False,
#   'cause': False,
#   'impressive': False,
#   'control': False,
#   'near': False,
#   'alone': False,
#   'suspense': False,
#   'straight': False,
#   'aspect': False,
#   'amaze': False,
#   '3': False,
#   'screenwriter': False,
#   'fast': False,
#   'reality': False,
#   'serious': False,
#   'van': False,
#   'crime': False,
#   'batman': False,
#   'critic': False,
#   'explain': False,
#   'jones': False,
#   'producer': False,
#   'robin': False,
#   'television': True,
#   'fly': False,
#   'red': False,
#   'fire': False,
#   'produce': False,
#   'agent': False,
#   'bill': False,
#   'office': False,
#   'george': False,
#   'presence': False,
#   'effort': False,
#   'subject': False,
#   'due': False,
#   'blood': False,
#   'told': False,
#   'street': False,
#   'certain': False,
#   'third': False,
#   'popular': False,
#   'important': False,
#   'read': False,
#   'mystery': False,
#   'attack': False,
#   'somehow': False,
#   'jim': False,
#   'country': False,
#   'appeal': False,
#   'teen': False,
#   'oh': False,
#   'motion': False,
#   'message': False,
#   'ryan': False,
#   'brings': False,
#   'doubt': False,
#   'musical': False,
#   'recent': False,
#   'prison': False,
#   'class': False,
#   'speak': False,
#   'previous': False,
#   'victim': False,
#   'successful': False,
#   'ago': False,
#   'rule': False,
#   'sexual': False,
#   'emotion': False,
#   'romance': False,
#   'throw': False,
#   'difficult': False,
#   'apparently': False,
#   'general': False,
#   'bunch': False,
#   'bob': False,
#   'effective': False,
#   'fail': False,
#   'ben': False,
#   'rich': True,
#   'dramatic': False,
#   'party': False,
#   'trouble': False,
#   'decides': False,
#   'dance': False,
#   'allow': False,
#   'anyway': False,
#   'clear': False,
#   'leaf': True,
#   'confuse': False,
#   'ability': False,
#   'predictable': False,
#   'smart': False,
#   'excellent': False,
#   'budget': False,
#   'annoy': False,
#   'lie': False,
#   'student': False,
#   'former': False,
#   'cross': False,
#   'somewhat': False,
#   'business': False,
#   'angel': False,
#   'brilliant': False,
#   'surprisingly': False,
#   'trailer': False,
#   'answer': False,
#   'date': False,
#   'company': False,
#   'definitely': False,
#   'williams': False,
#   'share': False,
#   'tone': False,
#   'intelligent': False,
#   'stone': False,
#   'rat': False,
#   'trek': False,
#   'choice': False,
#   'discover': False,
#   'personal': False,
#   'usual': False,
#   'handle': False,
#   'murphy': False,
#   'r': False,
#   'visual': False,
#   'towards': False,
#   'wedding': False,
#   'absolutely': False,
#   'truman': False,
#   'giant': False,
#   'us': False,
#   'capture': False,
#   'shock': False,
#   'familiar': False,
#   'animate': False,
#   'master': False,
#   'wear': False,
#   'b': False,
#   'bruce': False,
#   'similar': False,
#   'catch': False,
#   'grow': False,
#   'clever': False,
#   'track': False,
#   'adult': False,
#   '4': False,
#   'land': False,
#   'nature': False,
#   'term': False,
#   'favorite': False,
#   'bond': False,
#   'felt': False,
#   'potential': False,
#   'martin': True,
#   'pick': False,
#   'excite': False,
#   'suspect': False,
#   'ex': False,
#   'free': False,
#   'ultimately': False,
#   'huge': False,
#   'approach': False,
#   'prove': False,
#   'heard': False,
#   'la': False,
#   'step': False,
#   'seriously': False,
#   'box': False,
#   'beyond': False,
#   'color': False,
#   'likely': False,
#   'reveal': False,
#   'depth': False,
#   'travel': False,
#   'reach': False,
#   'unlike': False,
#   'richard': False,
#   'blue': False,
#   'society': False,
#   'sam': False,
#   'e': False,
#   'deliver': False,
#   'l': False,
#   'sister': False,
#   'hill': False,
#   'wood': False,
#   'non': False,
#   'otherwise': False,
#   'detective': False,
#   'cinema': False,
#   'park': False,
#   'inside': False,
#   'cold': False,
#   'personality': False,
#   'spirit': False,
#   'decent': False,
#   'door': False,
#   'continue': False,
#   'compare': False,
#   'strange': False,
#   'enjoyable': False,
#   'gag': False,
#   'dumb': False,
#   'arm': False,
#   'solid': False,
#   'sign': False,
#   'overall': False,
#   'disaster': False,
#   'succeed': False,
#   'particular': False,
#   'married': False,
#   'immediately': False,
#   'toy': False,
#   'thrill': False,
#   'week': False,
#   'amuse': False,
#   'mike': False,
#   'mess': False,
#   'sight': False,
#   'powerful': False,
#   'amount': False,
#   'hunt': False,
#   'mar': False,
#   'merely': False,
#   'player': False,
#   'scary': False,
#   '5': False,
#   'manage': False,
#   'race': False,
#   '90': False,
#   'treat': False,
#   'silly': False,
#   'key': False,
#   'cliche': False,
#   'today': False,
#   'various': False,
#   'grace': False,
#   'truth': False,
#   'ten': False,
#   'design': False,
#   'modern': False,
#   'join': False,
#   'cameron': False,
#   'hank': False,
#   'slightly': False,
#   'spend': False,
#   'roll': False,
#   'talented': False,
#   'government': False,
#   'appearance': False,
#   'month': False,
#   'west': False,
#   'hate': False,
#   'scott': False,
#   'island': False,
#   'steve': True,
#   'air': False,
#   'search': False,
#   'memorable': False,
#   'perfectly': False,
#   'drop': False,
#   'harry': False,
#   'fashion': False,
#   'neither': False,
#   'brought': False,
#   'impossible': False,
#   'political': False,
#   'tension': False,
#   'kiss': False,
#   'actual': False,
#   'rating': False,
#   'beauty': False,
#   'purpose': False,
#   'lover': False,
#   'train': False,
#   'club': False,
#   'fails': False,
#   'fi': False,
#   'max': False,
#   'strike': False,
#   'eddie': False,
#   'allen': False,
#   'sweet': False,
#   'list': False,
#   'partner': False,
#   'totally': False,
#   'mouth': False,
#   'introduce': False,
#   'haunt': False,
#   'earlier': False,
#   'sci': False,
#   'cannot': False,
#   'foot': False,
#   'building': False,
#   'suffer': False,
#   'pop': False,
#   'serve': False,
#   'adventure': False,
#   'frank': False,
#   'english': False,
#   'soundtrack': False,
#   'six': False,
#   'heavy': False,
#   'ridiculous': False,
#   'costume': False,
#   'notice': False,
#   'award': False,
#   'chan': False,
#   'quick': True,
#   'dress': False,
#   'menace': False,
#   'doctor': False,
#   'sell': False,
#   'monster': False,
#   'suit': False,
#   'bore': False,
#   'basic': False,
#   'animation': False,
#   'raise': False,
#   'leader': False,
#   'standard': False,
#   'atmosphere': False,
#   'struggle': False,
#   'flat': False,
#   'cheap': False,
#   'female': False,
#   'army': True,
#   'background': False,
#   'promise': False,
#   'opportunity': False,
#   'titanic': False,
#   'imagine': False,
#   'brief': False,
#   'minor': False,
#   'violent': False,
#   'ride': False,
#   'baby': False,
#   'require': False,
#   'woody': False,
#   'cinematography': False,
#   'suddenly': False,
#   'ground': False,
#   'bug': False,
#   'engage': False,
#   'cameo': False,
#   'dull': False,
#   'british': False,
#   'ghost': False,
#   'highly': False,
#   'animal': False,
#   'hear': False,
#   'plenty': False,
#   'private': False,
#   'impact': False,
#   'president': False,
#   'respect': False,
#   'edit': False,
#   'ii': False,
#   'steven': False,
#   '8': False,
#   'dollar': False,
#   'college': False,
#   'store': False,
#   'entirely': False,
#   'convincing': False,
#   'frame': False,
#   'front': False,
#   'language': False,
#   'grant': False,
#   'jerry': False,
#   'ape': False,
#   'episode': True,
#   'possibly': False,
#   'conclusion': False,
#   'road': False,
#   'seven': False,
#   'issue': False,
#   'godzilla': False,
#   'officer': True,
#   'test': False,
#   'common': False,
#   'french': False,
#   'encounter': False,
#   'lawyer': False,
#   'hardly': False,
#   'soldier': False,
#   'scientist': False,
#   'typical': False,
#   'edward': False,
#   'terrible': False,
#   'carrey': False,
#   'tarantino': False,
#   'rescue': False,
#   'development': False,
#   'slowly': False,
#   'creature': False,
#   'machine': False,
#   'recommend': False,
#   'tim': False,
#   'complex': False,
#   'rush': False,
#   'remain': False,
#   'thus': False,
#   'fantasy': False,
#   'chemistry': False,
#   'energy': False,
#   'travolta': False,
#   'period': False,
#   'brown': False,
#   'cinematic': False,
#   'sing': False,
#   'prof': False,
#   'hop': False,
#   'j': False,
#   'visit': False,
#   'longer': False,
#   'outside': False,
#   'sean': False,
#   'whatever': False,
#   'awful': False,
#   'hot': False,
#   'hong': False,
#   'clearly': False,
#   'okay': False,
#   'delivers': False,
#   'concept': False,
#   'realistic': False,
#   'draw': False,
#   'etc': False,
#   'meanwhile': False,
#   'criminal': False,
#   'constantly': False,
#   'admit': False,
#   'wall': False,
#   'forget': False,
#   'indeed': False,
#   'adam': False,
#   'thanks': False,
#   'fairly': False,
#   'sent': False,
#   'band': False,
#   'bizarre': False,
#   'spent': False,
#   'accent': False,
#   'storyline': False,
#   'singer': False,
#   'subplot': False,
#   'innocent': False,
#   'willis': False,
#   'brain': True,
#   'mary': False,
#   'frighten': False,
#   'subtle': False,
#   'ready': False,
#   'fellow': False,
#   'intrigue': False,
#   ...},
#  'neg')

# %%
from nltk import NaiveBayesClassifier

# %%
classifier = NaiveBayesClassifier.train(training_data)

# %%
nltk.classify.accuracy(classifier, testing_data)
# Out:
# 0.824

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#              outstanding = True              pos : neg    =     10.6 : 1.0
#               schumacher = True              neg : pos    =     10.3 : 1.0
#                    anger = True              pos : neg    =      9.4 : 1.0
#                   seagal = True              neg : pos    =      8.9 : 1.0
#                   turkey = True              neg : pos    =      7.8 : 1.0
#             respectively = True              pos : neg    =      7.6 : 1.0
#                  idiotic = True              neg : pos    =      6.9 : 1.0
#                    damon = True              pos : neg    =      6.8 : 1.0
#               uninspired = True              neg : pos    =      6.7 : 1.0
#                   castle = True              pos : neg    =      6.7 : 1.0
#                      gem = True              pos : neg    =      6.6 : 1.0
#              wonderfully = True              pos : neg    =      6.0 : 1.0
#                    awful = True              neg : pos    =      5.9 : 1.0
#                    inept = True              neg : pos    =      5.9 : 1.0
#                   spacey = True              pos : neg    =      5.8 : 1.0

# %%
from sklearn.svm import SVC
from nltk.classify.scikitlearn import SklearnClassifier

# %%
svc = SVC()
classifier_sklearn = SklearnClassifier(svc)

# %%
classifier_sklearn.train(training_data)
# Out:
# <SklearnClassifier(SVC())>

# %%
nltk.classify.accuracy(classifier_sklearn, testing_data)
# Out:
# 0.866

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
classifier_sklearn1 = SklearnClassifier(rfc)

# %%
classifier_sklearn1.train(training_data)
# Out:
# <SklearnClassifier(RandomForestClassifier())>

# %%
nltk.classify.accuracy(classifier_sklearn1, testing_data)
# Out:
# 0.832
